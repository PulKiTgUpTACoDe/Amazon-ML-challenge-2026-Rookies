# %%
import pandas as pd
import numpy as np
import os

# %%
data1 = pd.read_csv('../dataset/train/train_source1.tsv', sep='\t')
data2 = pd.read_csv('../dataset/train/train_source2.tsv', sep='\t')
data3 = pd.read_csv('../dataset/train/train_source3.tsv', sep='\t')
gt = pd.read_csv('../dataset/train/train_ground_truth.tsv', sep='\t')
data1.size, data2.size, data3.size
# Out:
# (8827284, 20138464, 21142412)

# %%
gt.head()
# Out:
#   source1_entity_id                                 matched_entity_ids
# 0      S1-777210964  S2-12029274,S2-407524980,S3-970714334,S3-71292...
# 1      S1-190133982             S2-523219173,S3-716445195,S3-986804760
# 2      S1-970131671                          S2-670035601,S3-392756625
# 3      S1-391999301  S2-742819060,S2-339356009,S2-233734305,S3-9388...
# 4      S1-435988542                                       S2-500704398
